# %% [markdown]
# # Making meltwater mask

# %%
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
import matplotlib.path as mpath
import xarray as xr
import cf_xarray
import cmocean as cm

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import gridspec

# %%
# Shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
# Land and contour data
# shelf_contour_1 = xr.open_dataset('/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc')['contour_masked_above']
# depth_1 = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/output050/20050501.ocean_static.nc')['deptho']
# land_mask_1 = (0 * depth_1).fillna(1)
# land_1 = xr.where(np.isnan(depth_1.rename('land_1')), 1, np.nan)

depth_2 = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')['ht']
land_mask_2 = (0 * depth_2).fillna(1)
land_2 = xr.where(np.isnan(depth_2.rename('land_2')), 1, np.nan)
depth_2_shelf, shelf_contour_2 = shelf_mask_isobath(depth_2, 'mom5')

# %%
var = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean.nc')['salt']
var = var.isel(time=0,st_ocean=0)
# Out:
# /jobfs/161682780.gadi-pbs/ipykernel_742096/1831344746.py:1: FutureWarning: In a future version, xarray will not decode the variable 'average_DT' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   var = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean.nc')['salt']
# ...

# %%
var
# Out:
# <xarray.DataArray 'salt' (yt_ocean: 2700, xt_ocean: 3600)> Size: 39MB
# [9720000 values with dtype=float32]
# Coordinates:
#   * yt_ocean  (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.89 89.94 89.98
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     st_ocean  float64 8B 0.5413
#     time      object 8B 1903-01-16 12:00:00
# Attributes:
#     long_name:      Practical Salinity
#     units:          psu
#     valid_range:    [-10. 100.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_salinity

# %%
var.where(land_mask_2==0).plot()

# %%
coast = var.where(land_mask_2==0.5)
coast.plot()

# %%
coast.max().compute()
# Out:
# <xarray.DataArray 'salt' ()> Size: 8B
# array(nan)
# Coordinates:
#     st_ocean  float64 8B 0.5413
#     time      object 8B 1903-01-16 12:00:00

# %% [markdown]
# ## Attempting mask build

# %%
land_mask = xr.where(np.isnan(depth_2), 1, 0)
ocean_mask = 1 - land_mask

# %%
# Cardinal directions
north = land_mask.shift(yt_ocean=-1)
south = land_mask.shift(yt_ocean=1)
east  = land_mask.shift(xt_ocean=-1)
west  = land_mask.shift(xt_ocean=1)

# %%
ocean_adjacent_to_land = (
    (ocean_mask == 1) &
    (
        (north == 1) |
        (south == 1) |
        (east  == 1) |
        (west  == 1)
    )
)

ocean_adjacent_to_land = ocean_adjacent_to_land.fillna(False)

# %%
ocean_adjacent_to_land = ocean_adjacent_to_land.astype(int)

# %%
var_SO = var.sel(yt_ocean=slice(None,-55))

# %%
var_SO.where(ocean_adjacent_to_land==1).plot()

# %%
var_SO.where(ocean_adjacent_to_land==1).sel(xt_ocean=slice(-150,-100),yt_ocean=slice(-78,-70)).plot()

# %% [markdown]
# Hm some gaps still, so need to improve

# %%
## Test adding diagonals 

# Cardinal directions
north = land_mask.shift(yt_ocean=-1)
south = land_mask.shift(yt_ocean=1)
east  = land_mask.shift(xt_ocean=-1)
west  = land_mask.shift(xt_ocean=1)

# Diagonals
ne = land_mask.shift(yt_ocean=-1, xt_ocean=1)
nw = land_mask.shift(yt_ocean=-1, xt_ocean=-1)
se = land_mask.shift(yt_ocean=1,  xt_ocean=1)
sw = land_mask.shift(yt_ocean=1,  xt_ocean=-1)

ocean_adjacent_to_land = (
    (ocean_mask == 1) &
    (
        (north == 1) | (south == 1) |
        (east  == 1) | (west  == 1) |
        (ne == 1) | (nw == 1) |
        (se == 1) | (sw == 1)
    )
).fillna(False)

# %%
var_SO.where(ocean_adjacent_to_land==1).plot()

# %%
var_SO.where(ocean_adjacent_to_land==1).sel(xt_ocean=slice(-150,-100),yt_ocean=slice(-78,-70)).plot()

# %% [markdown]
# Still a few gaps. Let's remind myself what the coastline looks like here.

# %%
var_SO.sel(xt_ocean=slice(-150,-100),yt_ocean=slice(-78,-70)).plot()

# %% [markdown]
# Right so it seems like its struggling with the straight north components of the coastline.

# %%
# Post check
var_SO.where(ocean_adjacent_to_land==1).sel(xt_ocean=slice(-110,-100),yt_ocean=slice(-74,-72)).plot()

# %% [markdown]
# ## Morphological dialoation test
# Equivalent to 'grow land by one cell, and then subtract original land'.

# %%
import scipy.ndimage as ndi

# %%
land_bool = np.isnan(depth_2.values)

# 8-connectivity structure
structure = np.ones((3,3))

dilated = ndi.binary_dilation(land_bool, structure=structure)

coastal_ocean = dilated & (~land_bool)

coastal_ocean = xr.DataArray(
    coastal_ocean,
    coords=depth_2.coords,
    dims=depth_2.dims
)

# %%
test = var_SO.where(coastal_ocean)
test.plot()

# %%
var_SO.where(coastal_ocean).sel(xt_ocean=slice(-150,-100),yt_ocean=slice(-78,-70)).plot()

# %%
# Post check
var_SO.where(coastal_ocean).sel(xt_ocean=slice(-110,-100),yt_ocean=slice(-74,-72)).plot()

# %% [markdown]
# Looks the same as above. Need to make a decision about whether we want 'steps' on the diagonals or not.

# %% [markdown]
# ## Distance transform test

# %%
# Land = True
land_bool = np.isnan(depth_2.values)

# Compute distance to nearest land cell
distance = ndi.distance_transform_edt(~land_bool)

# Ocean cells within 1 grid cell of land
coastal_ocean = (distance <= 1) & (~land_bool)

coastal_ocean = xr.DataArray(
    coastal_ocean,
    coords=depth_2.coords,
    dims=depth_2.dims
)

# %%
var_SO.where(coastal_ocean).sel(xt_ocean=slice(-150,-100),yt_ocean=slice(-78,-70)).plot()

# %% [markdown]
# Same issue. Checking if its just a display error:

# %%
var_SO.where(coastal_ocean).sel(xt_ocean=slice(-110,-100),yt_ocean=slice(-74,-72)).plot()

# %% [markdown]
# Lol it was just a display error. Confirming for other methods now above.
